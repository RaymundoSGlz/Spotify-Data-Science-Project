# %% [markdown]
# ## Importamos las librerías

# %%
import pandas as pd

# %% [markdown]
# ## Leemos los datos

# %%
df = pd.read_json("../Data/endsong.json") # cargamos el archivo json

# Mostramos los nombres de las columnas
df.columns
# Out:
# Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')

# %%
# Eliminamos las columnas innecesarias
df.drop(
    ['username', 'conn_country',
       'ip_addr_decrypted', 'user_agent_decrypted', 'spotify_track_uri', 'episode_name',
       'episode_show_name', 'spotify_episode_uri',
       'incognito_mode'], 
    axis=1,
    inplace=True
)
df.head()
# Out:
#                      ts                                     platform  \
# 0  2022-05-22T16:54:58Z           Windows 10 (10.0.22000; x64; AppX)
# 1  2022-08-16T12:48:28Z  Android OS 11 API 30 (Xiaomi, Redmi Note 8)
# 2  2022-08-16T03:08:14Z  Android OS 11 API 30 (Xiaomi, Redmi Note 8)
# 3  2023-03-10T02:52:41Z                                      android
# 4  2022-07-16T17:10:05Z           Windows 10 (10.0.22622; x64; AppX)
#
#    ms_played              master_metadata_track_name  \
# 0     166706           So Good (feat. Ty Dolla $ign)
# 1     239894                           Love Me Again
# 2       2900                       Víctima y Verdugo
# 3          0                       En Boca De Tantos
# 4     144686  Final del Juego (Avengers Endgame Rap)
#
#   master_metadata_album_artist_name        master_metadata_album_album_name  \
# 0                      Zara Larsson                                 So Good
# 1                       John Newman                                 Tribute
# 2                             Porta                        Algo Ha Cambiado
# 3                             Porta                       En Boca De Tantos
# 4                          Keyblade  Final del Juego (Avengers Endgame Rap)
#
#   reason_start reason_end  shuffle  skipped  offline  offline_timestamp
# 0    trackdone  trackdone     True      NaN    False      1653238330199
# 1       fwdbtn  trackdone    False      NaN    False      1660653867377
# 2       fwdbtn     fwdbtn     True      NaN    False      1660619290523
# 3       fwdbtn     fwdbtn     True      1.0     True         1678416760
# 4    trackdone     remote     True      NaN    False      1657986674400

# %%
# renombramos las columnas

df.rename(columns={'master_metadata_track_name': 'track_name', 'master_metadata_album_artist_name': 'album_artist_name', 'master_metadata_album_album_name': 'album_name'}, inplace=True)
df.sample(10)
# Out:
#                          ts  \
# 2442   2022-08-16T03:14:08Z
# 370    2022-07-14T12:25:44Z
# 2330   2022-09-09T20:21:10Z
# 6165   2022-09-01T00:10:31Z
# 7796   2022-08-19T04:09:56Z
# 8068   2022-08-01T03:34:16Z
# 9216   2023-03-07T09:44:39Z
# 12465  2023-03-31T20:36:47Z
# 11391  2022-08-21T19:45:39Z
# 6993   2022-10-23T23:39:06Z
#
#                                                 platform  ms_played  \
# 2442         Android OS 11 API 30 (Xiaomi, Redmi Note 8)     180066
# 370          Android OS 11 API 30 (Xiaomi, Redmi Note 8)      74375
# 2330   Partner amazon_salmon Amazon;Echo_Show_5;27d4d...      83069
# 6165         Android OS 11 API 30 (Xiaomi, Redmi Note 8)         23
# 7796   Partner amazon_salmon Amazon;Echo_Show_5;27d4d...     169724
# 8068         Android OS 11 API 30 (Xiaomi, Redmi Note 8)     253781
# 9216                                             android     119880
# 12465                                            windows     162360
# 11391  Partner amazon_salmon Amazon;Echo_Show_5;27d4d...     186850
# 6993                                             android       6204
#
#                           track_name album_artist_name  \
# 2442              Logro Desbloqueado             Porta
# 370                  Favor Con Favor          Santa RM
# 2330              Words Ain't Enough      Tessa Violet
# 6165        Los Más Buscados - Remix          Santa RM
# 7796                   Interlude III      Tessa Violet
# 8068                  Daño Colateral          Santa RM
# 9216                 Dragon Ball Rap             Porta
# 12465  YES MOM (I'm The One To Beat)      Tessa Violet
# 11391             decide to be happy       MisterWives
# 6993                      Same Drugs       MisterWives
#
#                           album_name reason_start reason_end  shuffle  \
# 2442                Algo Ha Cambiado    trackdone  trackdone     True
# 370                  Mala Ortografía    trackdone     logout     True
# 2330                       Bad Ideas    trackdone     remote    False
# 6165         Listo para Lo Que Venga       fwdbtn     fwdbtn     True
# 7796                       Bad Ideas    trackdone  trackdone     True
# 8068         Listo para Lo Que Venga    trackdone  trackdone     True
# 9216               En Boca De Tantos    trackdone  trackdone     True
# 12465  YES MOM (I'm The One To Beat)    trackdone  trackdone     True
# 11391                     SUPERBLOOM     clickrow  trackdone    False
# 6993                      Same Drugs      appload     remote     True
#
#        skipped  offline  offline_timestamp
# 2442       NaN    False      1660619466937
# 370        NaN    False      1657757776969
# 2330       NaN    False                  0
# 6165       NaN    False      1661991029335
# 7796       NaN    False                  0
# 8068       NaN    False      1659324599391
# 9216       0.0     True         1678182552
# 12465      0.0    False         1680294844
# 11391      NaN    False                  0
# 6993       0.0    False         1666568298

# %%
# Verificamos si tenemos valores faltantes
df.isnull().sum()
# Out:
# ts                      0
# platform                0
# ms_played               0
# track_name              3
# album_artist_name       3
# album_name              3
# reason_start            0
# reason_end              0
# shuffle                 0
# skipped              9295
# offline                 0
# offline_timestamp       0
# dtype: int64

# %%
# Verificamos que valores toma la variable skipped
df["skipped"].value_counts()
# Out:
# 0.0    3759
# 1.0    1683
# Name: skipped, dtype: int64

# %% [markdown]
# Dado que la variable se refiere a si saltamos una canción y toma el valor 1 si fue asi y 0 en el caso contrario, podemos deducir que una `NaN` se refiere a que no aplica el salto de la canción.
#
# Un ejemplo puede ser, porque se finalizo la reproducción. Por lo que podemos asignar el valor de 0, dado que si no se aplica el salto podemos entender que no se ha saltado la canción.

# %%
# Remplazamos los valores nulos por 0 en la variable "skipped"
df["skipped"].fillna(0, inplace=True)

# %%
# Verificamos nuevamente los valores nulos
df.isnull().sum()
# Out:
# ts                   0
# platform             0
# ms_played            0
# track_name           3
# album_artist_name    3
# album_name           3
# reason_start         0
# reason_end           0
# shuffle              0
# skipped              0
# offline              0
# offline_timestamp    0
# dtype: int64

# %%
# verificamos si donde hay valores nulos en una columna los hay en alguna otra
valores_nulos = df['album_artist_name'].isnull()
df[valores_nulos]
# Out:
#                          ts  \
# 129    2022-07-01T22:07:18Z
# 6754   2022-07-01T18:30:38Z
# 12990  2022-07-01T22:07:18Z
#
#                                                 platform  ms_played  \
# 129    web_player windows 10;chrome 102.0.5005.115;de...     455500
# 6754   web_player windows 10;chrome 101.0.4951.67;des...      90979
# 12990  web_player windows 10;chrome 102.0.5005.115;de...     558338
#
#       track_name album_artist_name album_name reason_start  \
# 129         None              None       None       remote
# 6754        None              None       None       remote
# 12990       None              None       None       remote
#
#                          reason_end  shuffle  skipped  offline  \
# 129    unexpected-exit-while-paused    False      0.0    False
# 6754                unexpected-exit    False      0.0    False
# 12990               unexpected-exit    False      0.0    False
#
#        offline_timestamp
# 129                    0
# 6754                   0
# 12990                  0

# %%
# Eliminamos las entradas con valores nulos
df.dropna(inplace=True, how="any")

# %%
# Verificamos nuestras variables para saber si es necesario hacer un cambio
df.dtypes
# Out:
# ts                    object
# platform              object
# ms_played              int64
# track_name            object
# album_artist_name     object
# album_name            object
# reason_start          object
# reason_end            object
# shuffle                 bool
# skipped              float64
# offline                 bool
# offline_timestamp      int64
# dtype: object

# %%
# observamos el contenido de ts
df["ts"].head()
# Out:
# 0    2022-05-22T16:54:58Z
# 1    2022-08-16T12:48:28Z
# 2    2022-08-16T03:08:14Z
# 3    2023-03-10T02:52:41Z
# 4    2022-07-16T17:10:05Z
# Name: ts, dtype: object

# %%
# Utilizamos los datos de ts para agregar las columnas de dia, mes y año
df['year'] = pd.DatetimeIndex(df["ts"]).year
df['month'] = pd.DatetimeIndex(df["ts"]).month
df['day'] = pd.DatetimeIndex(df["ts"]).day

# %%
# Eliminamos la columna ts
df.drop(columns=['ts'], inplace=True)

# %%
# Mostramos una muestra
df.sample(10)
# Out:
#                                                 platform  ms_played  \
# 304    Partner amazon_salmon Amazon;Echo_Show_5;27d4d...     179173
# 7084                  Windows 10 (10.0.22622; x64; AppX)     142893
# 1857         Android OS 12 API 31 (Xiaomi, Redmi Note 8)     157560
# 8175         Android OS 11 API 30 (Xiaomi, Redmi Note 8)     180066
# 14004                 Windows 10 (10.0.22000; x64; AppX)      19955
# 12274        Android OS 11 API 30 (Xiaomi, Redmi Note 8)       2747
# 9408         Android OS 11 API 30 (Xiaomi, Redmi Note 8)     253200
# 5889                                      not_applicable     197337
# 727                                              android     203573
# 8088         Android OS 12 API 31 (Xiaomi, Redmi Note 8)     232186
#
#                                           track_name album_artist_name  \
# 304                                        Bad Ideas      Tessa Violet
# 7084       Jingle Bell Rock -Spotify Singles Holiday       MisterWives
# 1857   Sunflower - Spider-Man: Into the Spider-Verse       Post Malone
# 8175                              Logro Desbloqueado             Porta
# 14004                                  En Este Track          Santa RM
# 12274                             Logro Desbloqueado             Porta
# 9408                                         Riptide       MisterWives
# 5889                       In Your Eyes - Radio Edit              INNA
# 727        La Locura Está en Mí - Streaming Remaster         Santaflow
# 8088                                   Our Own House       MisterWives
#
#                                       album_name reason_start reason_end  \
# 304                                    Bad Ideas    trackdone  trackdone
# 7084   Jingle Bell Rock -Spotify Singles Holiday       fwdbtn  trackdone
# 1857                        Hollywood's Bleeding       fwdbtn  trackdone
# 8175                            Algo Ha Cambiado    trackdone  trackdone
# 14004                                  Bajo Cero    trackdone     fwdbtn
# 12274                           Algo Ha Cambiado       fwdbtn     fwdbtn
# 9408                            Spotify Sessions    trackdone  trackdone
# 5889                                In Your Eyes    trackdone  trackdone
# 727                                    Ave Fénix    trackdone  trackdone
# 8088                               Our Own House    trackdone  trackdone
#
#        shuffle  skipped  offline  offline_timestamp  year  month  day
# 304      False      0.0    False                  0  2022      8   14
# 7084      True      0.0    False      1659907601866  2022      8    7
# 1857      True      0.0     True      1648137661727  2022      3   24
# 8175      True      0.0    False      1659742696382  2022      8    5
# 14004     True      0.0    False      1650059141697  2022      4   15
# 12274     True      0.0    False      1660870701973  2022      8   19
# 9408      True      0.0     True      1649155983265  2022      4    5
# 5889     False      0.0    False                  0  2022     11    1
# 727       True      0.0     True         1678168983  2023      3    7
# 8088      True      0.0    False      1647967059327  2022      3   22

# %%
# Cambiamos ms_played a s_played convirtiendo de milisegundos a segundos

def convert_ms_to_s(ms_played):
    return ms_played / 1000

# Aplicamos la función
df["s_played"] = df["ms_played"].apply(convert_ms_to_s)

# Eliminamos la columna ms_played
df.drop("ms_played", axis=1, inplace=True)

# %%
# revisamos el dataset
df.sample(10)
# Out:
#                                                 platform  \
# 11450        Android OS 11 API 30 (Xiaomi, Redmi Note 8)
# 13762        Android OS 11 API 30 (Xiaomi, Redmi Note 8)
# 5195                                             android
# 3479                                             windows
# 5247                                             android
# 2316                                             android
# 12689                                            windows
# 10237  Partner amazon_salmon Amazon;Echo_Show_5;27d4d...
# 11297        Android OS 12 API 31 (Xiaomi, Redmi Note 8)
# 5910         Android OS 11 API 30 (Xiaomi, Redmi Note 8)
#
#                                       track_name album_artist_name  \
# 11450                      No Sé en Qué Te Fallé          Santa RM
# 13762                           Realidad Virtual             Porta
# 5195                             Un Par De Balas             C-Kan
# 3479                                   Bang Bang            K'NAAN
# 5247   La Locura Está en Mí - Streaming Remaster         Santaflow
# 2316                                Chasing This       MisterWives
# 12689        I Really Want to Stay at Your House       Rosa Walton
# 10237                               Kitchen Song      Tessa Violet
# 11297                                    FRIENDS        Marshmello
# 5910                           Come to Me Slowly      Margo Guryan
#
#                                               album_name reason_start  \
# 11450                                    Mala Ortografía    trackdone
# 13762                                         Equilibrio       fwdbtn
# 5195                               Clasificacion C Vol.1       fwdbtn
# 3479                                          Troubadour    trackdone
# 5247                                           Ave Fénix    trackdone
# 2316                                    Connect The Dots       fwdbtn
# 12689  Cyberpunk 2077: Radio, Vol. 2 (Original Soundt...    trackdone
# 10237                                       Kitchen Song    trackdone
# 11297                                    Speak Your Mind    trackdone
# 5910                                            27 Demos    trackdone
#
#       reason_end  shuffle  skipped  offline  offline_timestamp  year  month  \
# 11450     fwdbtn     True      0.0    False      1658532523878  2022      7
# 13762     fwdbtn     True      0.0    False      1650366060099  2022      4
# 5195      fwdbtn     True      1.0     True         1677896799  2023      3
# 3479   trackdone    False      0.0    False         1674414726  2023      1
# 5247   trackdone     True      0.0     True         1671720277  2022     12
# 2316      fwdbtn     True      1.0    False         1667939355  2022     11
# 12689  trackdone    False      0.0    False                  0  2022     12
# 10237  trackdone    False      0.0    False                  0  2022      8
# 11297  trackdone     True      0.0     True      1648468721865  2022      3
# 5910   trackdone    False      0.0    False      1661048586565  2022      8
#
#        day  s_played
# 11450   22    28.717
# 13762   19     0.023
# 5195     4     1.843
# 3479    22   186.533
# 5247    22   203.573
# 2316     8     0.957
# 12689   19   246.422
# 10237   14   155.080
# 11297   28   202.620
# 5910    21   142.813

# %%
# inspeccionamos los valores que toma la columna "platform"
df["platform"].unique()
# Out:
# array(['Windows 10 (10.0.22000; x64; AppX)',
#        'Android OS 11 API 30 (Xiaomi, Redmi Note 8)', 'android',
#        'Windows 10 (10.0.22622; x64; AppX)',
#        'Android OS 12 API 31 (Xiaomi, Redmi Note 8)',
#        'Windows 10 (10.0.19042; x64; AppX)',
#        'Partner amazon_salmon Amazon;Echo_Show_5;27d4dfe427b34d57995b463e5d63198d;;tpapi',
#        'windows', 'web_player windows 10;chrome 101.0.4951.67;desktop',
#        'Windows 10 (10.0.22621; x64; AppX)',
#        'web_player windows 10;chrome 102.0.5005.115;desktop',
#        'web_player windows 10;chrome 100.0.4896.127;desktop',
#        'Android OS 12 API 32 (Xiaomi, Redmi Note 8)', 'not_applicable',
#        'Linux [x86-64 0]',
#        'web_player windows 10;chrome 103.0.5060.114;desktop',
#        'web_player windows 10;chrome 103.0.5060.134;desktop',
#        'web_player windows 10;chrome 99.0.4844.84;desktop',
#        'Linux Ubuntu Core 18 (snap package) [x86-64 0]',
#        'web_player windows 10;chrome 104.0.5112.102;desktop',
#        'Windows 10 (10.0.19043; x64; AppX)',
#        'web_player windows 10;microsoft edge 99.0.1150.30;desktop',
#        'Partner google cast_tv;B820C-A15;;5.16.3--1.52.253741',
#        'web_player linux undefined;firefox 95.0;desktop'], dtype=object)

# %%
# Definimos una función para agrupar las plataformas
# evitando la distinción entre versiones de android y windows
# juntando los navegadores web
# Definir la función reasignar()
def reasignar(valor):
    if 'android' in valor.lower():
        return 'Android'
    elif 'windows' in valor.lower():
        return 'Windows'
    elif 'edge' in valor.lower() or 'chrome' in valor.lower():
        return 'Web-browser'
    elif 'linux' in valor.lower():
        return 'Linux'
    else:
        return 'Otros'

# Aplicar la función a la columna "platform"
df['platform'] = df['platform'].apply(reasignar)

# %%
# Visualizamos la forma final de nuestro dataset
df.sample(10)
# Out:
#       platform                                         track_name  \
# 10390  Android                                              Bored
# 9861   Android                               Zombies on Your Lawn
# 5011   Android                                            FRIENDS
# 3252   Android      Sunflower - Spider-Man: Into the Spider-Verse
# 9922   Android                                        Sé Tu Mismo
# 6038     Otros                                         My Brother
# 6617   Android                  Quiero Que Sepas (feat. MC Magic)
# 13585  Android  The Spectacular Spider-Man Main Theme (From "T...
# 5829   Android                                            Estados
# 12264  Android                                              Crush
#
#       album_artist_name                                         album_name  \
# 10390      Tessa Violet                                              Bored
# 9861    Laura Shigihara  Plants Vs. Zombies (Original Video Game Soundt...
# 5011         Marshmello                                    Speak Your Mind
# 3252        Post Malone                  Spider-Man: Into the Spider-Verse
# 9922              Porta                                        Sé Tu Mismo
# 6038        MisterWives                                   Connect The Dots
# 6617              C-Kan                              Clasificacion C Vol.1
# 13585        Geek Music  The Spectacular Spider-Man Main Theme (From "T...
# 5829              Porta                        No Hay Truco (Maqueta 2007)
# 12264      Tessa Violet                                              Crush
#
#       reason_start reason_end  shuffle  skipped  offline  offline_timestamp  \
# 10390     clickrow    endplay    False      0.0    False      1637719690723
# 9861      clickrow    endplay    False      0.0    False      1646577238724
# 5011     trackdone  trackdone     True      0.0     True         1677879876
# 3252        fwdbtn     fwdbtn     True      1.0     True         1678421174
# 9922        fwdbtn     fwdbtn     True      0.0    False      1659398091404
# 6038        fwdbtn     fwdbtn     True      0.0    False                  0
# 6617     trackdone  trackdone     True      0.0     True         1678172255
# 13585    trackdone  trackdone     True      0.0    False      1638446818216
# 5829     trackdone  trackdone     True      0.0     True         1678164282
# 12264    trackdone  trackdone     True      0.0    False         1678412346
#
#        year  month  day  s_played
# 10390  2021     11   24     6.430
# 9861   2022      3    6     8.050
# 5011   2023      3    3   202.620
# 3252   2023      3   10     2.030
# 9922   2022      8    1     2.335
# 6038   2022     10    8     9.896
# 6617   2023      3    7   218.075
# 13585  2021     12    2   150.879
# 5829   2023      3    7   300.826
# 12264  2023      3   10   216.266

# %%
# Exportamos el dataset en un archivo csv
df.to_csv('../Data/Spotify_data.csv', index=False)
